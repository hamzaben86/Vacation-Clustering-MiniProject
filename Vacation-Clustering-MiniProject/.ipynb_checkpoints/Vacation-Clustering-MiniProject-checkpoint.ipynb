# %% [markdown]
# # Using Unsupervised Learning to plan her Paris Vacation: A Clustering Problem

# %% [markdown]
# ## Preparing the data

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup as Soup

# %% [markdown]
# ## k-means Clustering of Geo Locations

# %%
map_kml = "doc.kml" # imported kml file from Google Maps
with open('doc.kml') as data:
    kml_soup = Soup(data, 'lxml-xml') # Parse as XML
coords = kml_soup.find_all('coordinates') # find all the coordinates
coords_list = []
for x in coords:
    coords_list.append(str(x)) # store the coordinates in a list

# %%
names = kml_soup.find_all('name') # find all the coordinates
names_list = []
for x in names:
    names_list.append(str(x)) # store the coordinates in a list

# %%
# create new dataframe
coord_col = ['Longitude', 'Latitude', 'Landmark']
df_coord = pd.DataFrame(columns=coord_col) 
# split coordinates list into coordinates to populate the dataframe
for i, j in zip(range(len(coords_list)), range(2, len(names_list))):
    item = coords_list[i]
    string_split = item.split(',')
    coord1 = float(string_split[0][26:])
    coord2 = float(string_split[1])
    coord3 = names_list[j][6:-7]
    df_coord.loc[i] = [coord1, coord2, coord3]

# %%
df_coord
# Out:
#     Longitude   Latitude                                   Landmark
# 0    2.328729  48.846361        French Alliance Paris Ile-De-France
# 1    2.289282  48.861596                          Trocadéro Gardens
# 2    2.294483  48.858370                               Eiffel Tower
# 3    2.340802  48.886503                            Place du Tertre
# 4    2.343023  48.886706  The Basilica of the Sacred Heart of Paris
# 5    2.300375  48.871669        Louis Vuitton Maison Champs Élysées
# 6    2.330479  48.873820                         Galeries Lafayette
# 7    2.327793  48.873977                        Printemps Haussmann
# 8    2.331767  48.871934                             Palais Garnier
# 9    2.337644  48.860611                              Louvre Museum
# 10   2.120355  48.804865                       Palace of Versailles
# 11   2.305937  48.864011                Boat Trip (Bateaux-Mouches)
# 12   2.775808  48.872234                           Disneyland Paris
# 13   2.352245  48.860642                        The Centre Pompidou
# 14   2.349902  48.852968             Cathédrale Notre-Dame de Paris
# 15   2.337160  48.846222                         Luxembourg Gardens
# 16   2.341325  48.857050                                  Pont Neuf
# 17   2.784017  48.853465                          La Vallée Village
# 18   2.307314  48.865784                             Champs-Élysées
# 19   2.325417  48.860501                         Gare Musée d'Orsay
# 20   2.436470  48.842348               Sainte-Chapelle de Vincennes
# 21   2.322672  48.863788                           Orangerie Museum
# 22   2.358804  48.858703                                  Le Marais
# 23   2.315785  48.855334                                Musée Rodin
# 24   2.333328  48.853798                     Saint-Germain-des-Prés
# 25   2.310532  48.875448                     Musée Jacquemart-André

# %%
df_coord.to_csv('df_coord.csv')

# %%
from sklearn.cluster import KMeans # Importing KMeans
# Creating an instance of KMeans to find 10 clusters
kmeans_1 = KMeans(n_clusters=10)
# Using fit_predict to cluster the dataset
X = df_coord[['Longitude','Latitude']].values
predictions = kmeans_1.fit_predict(X)

# %%
clustered = pd.concat([df_coord.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)

# %%
clustered.drop('index', axis=1, inplace=True)

# %%
conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,
    clustered['Cluster'] == 5,
    clustered['Cluster'] == 6,
    clustered['Cluster'] == 7,
    clustered['Cluster'] == 8,
    clustered['Cluster'] == 9 ]
choices = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday', 
           'Sunday', 'Monday', 'Tuesday', 'Wednesday' ]
clustered['Vacation Day'] = np.select(conditions, choices, default='black')

# %%
clustered.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                                   Landmark  Cluster  \
# 1    2.289282  48.861596                          Trocadéro Gardens        0
# 2    2.294483  48.858370                               Eiffel Tower        0
# 12   2.775808  48.872234                           Disneyland Paris        1
# 17   2.784017  48.853465                          La Vallée Village        1
# 22   2.358804  48.858703                                  Le Marais        2
# 13   2.352245  48.860642                        The Centre Pompidou        2
# 14   2.349902  48.852968             Cathédrale Notre-Dame de Paris        2
# 10   2.120355  48.804865                       Palace of Versailles        3
# 20   2.436470  48.842348               Sainte-Chapelle de Vincennes        4
# 6    2.330479  48.873820                         Galeries Lafayette        5
# 7    2.327793  48.873977                        Printemps Haussmann        5
# 8    2.331767  48.871934                             Palais Garnier        5
# 23   2.315785  48.855334                                Musée Rodin        6
# 21   2.322672  48.863788                           Orangerie Museum        6
# 19   2.325417  48.860501                         Gare Musée d'Orsay        6
# 0    2.328729  48.846361        French Alliance Paris Ile-De-France        6
# 16   2.341325  48.857050                                  Pont Neuf        7
# 24   2.333328  48.853798                     Saint-Germain-des-Prés        7
# 9    2.337644  48.860611                              Louvre Museum        7
# 15   2.337160  48.846222                         Luxembourg Gardens        7
# 4    2.343023  48.886706  The Basilica of the Sacred Heart of Paris        8
# 3    2.340802  48.886503                            Place du Tertre        8
# 18   2.307314  48.865784                             Champs-Élysées        9
# 11   2.305937  48.864011                Boat Trip (Bateaux-Mouches)        9
# 5    2.300375  48.871669        Louis Vuitton Maison Champs Élysées        9
# 25   2.310532  48.875448                     Musée Jacquemart-André        9
#
#    Vacation Day
# 1        Monday
# 2        Monday
# 12      Tuesday
# 17      Tuesday
# 22    Wednesday
# 13    Wednesday
# 14    Wednesday
# 10     Thursday
# 20       Friday
# 6      Saturday
# 7      Saturday
# 8      Saturday
# 23       Sunday
# 21       Sunday
# 19       Sunday
# 0        Sunday
# 16       Monday
# 24       Monday
# 9        Monday
# 15       Monday
# 4       Tuesday
# 3       Tuesday
# 18    Wednesday
# 11    Wednesday
# 5     Wednesday
# 25    Wednesday

# %%
clustered.to_csv('clustered.csv')

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
centers = kmeans_1.cluster_centers_
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Longitude', fontsize=18)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.colorbar(ticks=np.linspace(0,9,10))
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
#plt.xlim(2.28, 2.375)
#plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=10)', fontsize=14)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.colorbar(ticks=np.linspace(0,9,10))
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
plt.xlim(2.28, 2.375)
plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=10)', fontsize=14)
plt.grid()
plt.show()

# %%
import hdbscan

# %%
rads = np.radians(X)
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, metric='haversine')
predictions = clusterer.fit_predict(rads)

# %%
clustered = pd.concat([df_coord.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)
clustered.drop('index', axis=1, inplace=True)
conditions = [
    clustered['Cluster'] == -1, 
    clustered['Cluster'] == 0,
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,
    clustered['Cluster'] == 5,
    clustered['Cluster'] == 6,
    clustered['Cluster'] == 7,
    clustered['Cluster'] == 8 ]
choices = ['NA/Noise', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 
           'Friday','Saturday', 'Sunday', 'Monday', 'Tuesday' ]
clustered['Vacation Day'] = np.select(conditions, choices, default='black')
clustered.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                                   Landmark  Cluster  \
# 23   2.315785  48.855334                                Musée Rodin       -1
# 20   2.436470  48.842348               Sainte-Chapelle de Vincennes       -1
# 10   2.120355  48.804865                       Palace of Versailles       -1
# 12   2.775808  48.872234                           Disneyland Paris        0
# 17   2.784017  48.853465                          La Vallée Village        0
# 3    2.340802  48.886503                            Place du Tertre        1
# 4    2.343023  48.886706  The Basilica of the Sacred Heart of Paris        1
# 1    2.289282  48.861596                          Trocadéro Gardens        2
# 2    2.294483  48.858370                               Eiffel Tower        2
# 18   2.307314  48.865784                             Champs-Élysées        3
# 11   2.305937  48.864011                Boat Trip (Bateaux-Mouches)        3
# 25   2.310532  48.875448                     Musée Jacquemart-André        3
# 5    2.300375  48.871669        Louis Vuitton Maison Champs Élysées        3
# 8    2.331767  48.871934                             Palais Garnier        4
# 7    2.327793  48.873977                        Printemps Haussmann        4
# 6    2.330479  48.873820                         Galeries Lafayette        4
# 19   2.325417  48.860501                         Gare Musée d'Orsay        5
# 21   2.322672  48.863788                           Orangerie Museum        5
# 13   2.352245  48.860642                        The Centre Pompidou        6
# 14   2.349902  48.852968             Cathédrale Notre-Dame de Paris        6
# 22   2.358804  48.858703                                  Le Marais        6
# 15   2.337160  48.846222                         Luxembourg Gardens        7
# 0    2.328729  48.846361        French Alliance Paris Ile-De-France        7
# 24   2.333328  48.853798                     Saint-Germain-des-Prés        8
# 16   2.341325  48.857050                                  Pont Neuf        8
# 9    2.337644  48.860611                              Louvre Museum        8
#
#    Vacation Day
# 23     NA/Noise
# 20     NA/Noise
# 10     NA/Noise
# 12       Monday
# 17       Monday
# 3       Tuesday
# 4       Tuesday
# 1     Wednesday
# 2     Wednesday
# 18     Thursday
# 11     Thursday
# 25     Thursday
# 5      Thursday
# 8        Friday
# 7        Friday
# 6        Friday
# 19     Saturday
# 21     Saturday
# 13       Sunday
# 14       Sunday
# 22       Sunday
# 15       Monday
# 0        Monday
# 24      Tuesday
# 16      Tuesday
# 9       Tuesday

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.gnuplot2
#norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, s=100, edgecolor='none')
plt.colorbar(ticks=[-1,0,1,2,3,4,5,6,7,8])
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
#plt.xlim(2.28, 2.375)
#plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('HDBSCAN clustering results', fontsize=14)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.gnuplot2
#norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, s=100, edgecolor='none')
plt.colorbar(ticks=[-1,0,1,2,3,4,5,6,7,8])
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
plt.xlim(2.28, 2.375)
plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=10)', fontsize=14)
plt.grid()
plt.show()
